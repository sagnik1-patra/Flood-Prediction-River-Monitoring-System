# %%
import os
import json
import yaml
import joblib
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
from sklearn.model_selection import train_test_split
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, LSTM, Dense, Conv1D, Flatten, Dropout, concatenate
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.optimizers import Adam
import tensorflow as tf


BASE_DIR = r"C:\Users\NXTWAVE\Downloads\Flood Prediction & River-Monitoring System"
DATA_PATH = os.path.join(BASE_DIR, "archive", "flood.csv")
VIS_DIR = os.path.join(BASE_DIR, "visuals")
os.makedirs(VIS_DIR, exist_ok=True)

# =========================================================
# 📊 LOAD DATA
# =========================================================
print("[INFO] Loading dataset...")
df = pd.read_csv(DATA_PATH)
print("[INFO] Shape:", df.shape)
print("[INFO] Columns:", df.columns.tolist())

df = df.dropna()

# Last column = FloodProbability (regression target)
y = df.iloc[:, -1].values.reshape(-1, 1)
X = df.iloc[:, :-1].values

scaler = MinMaxScaler()
X_scaled = scaler.fit_transform(X)
joblib.dump(scaler, os.path.join(BASE_DIR, "ais_gwo_stormshield_scaler.pkl"))

X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size=0.2, random_state=42)

# =========================================================
# 🧱 MODEL BUILDER (CNN + LSTM)
# =========================================================
def build_model(lr=0.001, dropout_rate=0.3, units=64):
    # CNN branch
    cnn_input = Input(shape=(X_train.shape[1], 1))
    conv = Conv1D(filters=32, kernel_size=3, activation='relu')(cnn_input)
    flat = Flatten()(conv)

    # LSTM branch
    lstm_input = Input(shape=(X_train.shape[1], 1))
    lstm = LSTM(units, return_sequences=False)(lstm_input)

    # Merge
    merged = concatenate([flat, lstm])
    dense1 = Dense(64, activation='relu')(merged)
    drop = Dropout(dropout_rate)(dense1)
    output = Dense(1, activation='linear')(drop)  # regression output

    model = Model(inputs=[cnn_input, lstm_input], outputs=output)
    model.compile(optimizer=Adam(learning_rate=lr), loss='mse', metrics=['mae'])
    return model

# =========================================================
# 🧬 HYBRID AIS + GWO OPTIMIZER
# =========================================================
def hybrid_ais_gwo(objective_func, dim, bounds, n_agents=4, max_iter=6):
    lb, ub = bounds
    population = np.random.uniform(lb, ub, (n_agents, dim))
    fitness = np.array([objective_func(ind) for ind in population])
    best_idx = np.argmin(fitness)
    best = population[best_idx].copy()
    best_score = fitness[best_idx]

    for t in range(max_iter):
        a = 2 - 2 * (t / max_iter)
        for i in range(n_agents):
            A = 2 * a * np.random.rand(dim) - a
            C = 2 * np.random.rand(dim)
            j = np.random.randint(n_agents)
            D = abs(C * population[j] - population[i])
            X_new = population[j] - A * D

            # AIS mutation
            mutation = np.random.randn(dim) * 0.05
            X_new = np.clip(X_new + mutation, lb, ub)

            new_fit = objective_func(X_new)
            if new_fit < fitness[i]:
                fitness[i] = new_fit
                population[i] = X_new

        best_idx = np.argmin(fitness)
        if fitness[best_idx] < best_score:
            best_score = fitness[best_idx]
            best = population[best_idx].copy()

        print(f"[ITER {t+1}] Best MAE: {best_score:.6f}")

    return best, best_score

# =========================================================
# 🎯 OBJECTIVE FUNCTION (MAE MINIMIZATION)
# =========================================================
def proxy_objective(params):
    lr, dropout_rate, units = params
    units = int(units)
    model = build_model(lr, dropout_rate, units)
    model.fit([X_train[..., np.newaxis], X_train[..., np.newaxis]],
              y_train, epochs=3, batch_size=32, verbose=0)
    loss, mae = model.evaluate([X_test[..., np.newaxis], X_test[..., np.newaxis]], y_test, verbose=0)
    return mae  # minimize MAE

# =========================================================
# ⚙️ RUN OPTIMIZATION
# =========================================================
print("[INFO] Running AIS+GWO optimization...")
best_params, best_score = hybrid_ais_gwo(
    objective_func=lambda x: proxy_objective(x),
    dim=3,
    bounds=([0.0001, 0.1, 32], [0.01, 0.5, 128]),
    n_agents=4,
    max_iter=5
)

best_lr, best_dropout, best_units = best_params
best_units = int(best_units)

with open(os.path.join(BASE_DIR, "ais_gwo_stormshield_config.yaml"), "w") as f:
    yaml.dump({
        'optimizer': 'Hybrid AIS + GWO (Regression)',
        'best_params': {
            'learning_rate': float(best_lr),
            'dropout_rate': float(best_dropout),
            'units': int(best_units)
        },
        'best_MAE': float(best_score)
    }, f)

# =========================================================
# 🧠 FINAL TRAINING
# =========================================================
model = build_model(best_lr, best_dropout, best_units)
early = EarlyStopping(patience=10, restore_best_weights=True)

history_model = model.fit([X_train[..., np.newaxis], X_train[..., np.newaxis]],
                          y_train, validation_split=0.2,
                          epochs=50, batch_size=32,
                          callbacks=[early], verbose=1)

model.save(os.path.join(BASE_DIR, "ais_gwo_stormshield_model.h5"))

# =========================================================
# 📈 EVALUATION & VISUALS
# =========================================================
y_pred = model.predict([X_test[..., np.newaxis], X_test[..., np.newaxis]])
mae = mean_absolute_error(y_test, y_pred)
rmse = mean_squared_error(y_test, y_pred, squared=False)
r2 = r2_score(y_test, y_pred)

print(f"[INFO] MAE={mae:.4f} | RMSE={rmse:.4f} | R²={r2:.4f}")

# Comparison Plot
plt.figure(figsize=(8,4))
plt.plot(y_test[:100], label='Actual')
plt.plot(y_pred[:100], label='Predicted')
plt.legend()
plt.title("Flood Probability (Actual vs Predicted)")
plt.savefig(os.path.join(VIS_DIR, "ais_gwo_stormshield_comparison_graph.png"))
plt.close()

# Loss Curve
plt.figure(figsize=(8,4))
plt.plot(history_model.history['loss'], label='Train')
plt.plot(history_model.history['val_loss'], label='Val')
plt.legend()
plt.title("Loss Curve (MSE)")
plt.savefig(os.path.join(VIS_DIR, "ais_gwo_stormshield_loss_graph.png"))
plt.close()

# Correlation Heatmap
corr = pd.DataFrame(np.hstack((y_test, y_pred)), columns=["True", "Predicted"]).corr()
sns.heatmap(corr, annot=True, cmap="coolwarm")
plt.title("True vs Predicted Correlation")
plt.savefig(os.path.join(VIS_DIR, "ais_gwo_stormshield_heatmap.png"))
plt.close()

# =========================================================
# 💾 SAVE RESULTS
# =========================================================
pred_json = {"MAE": float(mae), "RMSE": float(rmse), "R2": float(r2)}
with open(os.path.join(BASE_DIR, "ais_gwo_stormshield_prediction.json"), "w") as f:
    json.dump(pred_json, f, indent=4)

pd.DataFrame({"True": y_test.flatten(), "Predicted": y_pred.flatten()}).to_csv(
    os.path.join(BASE_DIR, "ais_gwo_stormshield_result.csv"), index=False
)

print("[✅] All files saved successfully in:", BASE_DIR)
# Out:
# WARNING:tensorflow:From C:\Users\NXTWAVE\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.
#
50
# 1000/1000 [==============================] - 8s 8ms/step - loss: 5.5243e-05 - mae: 0.0051 - val_loss: 5.9498e-06 - val_mae: 0.0021
# Epoch 24/50
# 1000/1000 [==============================] - 8s 8ms/step - loss: 5.4137e-05 - mae: 0.0050 - val_loss: 2.4823e-06 - val_mae: 0.0012
# Epoch 25/50
# 1000/1000 [==============================] - 8s 8ms/step - loss: 5.2550e-05 - mae: 0.0050 - val_loss: 5.2607e-06 - val_mae: 0.0019
# Epoch 26/50
# 1000/1000 [==============================] - 8s 8ms/step - loss: 5.3975e-05 - mae: 0.0050 - val_loss: 4.1768e-06 - val_mae: 0.0017
# Epoch 27/50
# 1000/1000 [==============================] - 8s 8ms/step - loss: 5.2012e-05 - mae: 0.0050 - val_loss: 4.2782e-06 - val_mae: 0.0016
# Epoch 28/50
# 1000/1000 [==============================] - 8s 8ms/step - loss: 5.2655e-05 - mae: 0.0050 - val_loss: 4.7651e-06 - val_mae: 0.0018
# Epoch 29/50
# 1000/1000 [==============================] - 8s 8ms/step - loss: 5.2540e-05 - mae: 0.0049 - val_loss: 4.2432e-06 - val_mae: 0.0017
# Epoch 30/50
# 1000/1000 [==============================] - 8s 8ms/step - loss: 5.1786e-05 - mae: 0.0049 - val_loss: 1.4434e-06 - val_mae: 9.4143e-04
# Epoch 31/50
# 1000/1000 [==============================] - 8s 8ms/step - loss: 5.0523e-05 - mae: 0.0049 - val_loss: 2.0856e-06 - val_mae: 0.0011
# Epoch 32/50
# 1000/1000 [==============================] - 8s 8ms/step - loss: 5.1877e-05 - mae: 0.0049 - val_loss: 3.1268e-06 - val_mae: 0.0014
# Epoch 33/50
# 1000/1000 [==============================] - 8s 8ms/step - loss: 5.1820e-05 - mae: 0.0049 - val_loss: 3.7092e-06 - val_mae: 0.0016
# Epoch 34/50
# 1000/1000 [==============================] - 8s 8ms/step - loss: 5.2093e-05 - mae: 0.0049 - val_loss: 4.0600e-06 - val_mae: 0.0016
# Epoch 35/50
# 1000/1000 [==============================] - 8s 8ms/step - loss: 5.0954e-05 - mae: 0.0048 - val_loss: 1.6581e-06 - val_mae: 9.9159e-04
# Epoch 36/50
# 1000/1000 [==============================] - 8s 8ms/step - loss: 5.1601e-05 - mae: 0.0049 - val_loss: 1.7271e-06 - val_mae: 0.0010
# Epoch 37/50
# 1000/1000 [==============================] - 8s 8ms/step - loss: 5.0467e-05 - mae: 0.0048 - val_loss: 2.4293e-06 - val_mae: 0.0013
# Epoch 38/50
# 1000/1000 [==============================] - 8s 8ms/step - loss: 4.9751e-05 - mae: 0.0048 - val_loss: 4.9184e-06 - val_mae: 0.0020
# Epoch 39/50
# 1000/1000 [==============================] - 8s 8ms/step - loss: 5.1806e-05 - mae: 0.0049 - val_loss: 1.5909e-06 - val_mae: 0.0010
# Epoch 40/50
# 1000/1000 [==============================] - 8s 8ms/step - loss: 5.1248e-05 - mae: 0.0049 - val_loss: 2.3709e-06 - val_mae: 0.0013
# C:\Users\NXTWAVE\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\engine\training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 313/313 [==============================] - 2s 4ms/step
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[1], line 165
#     163 y_pred = model.predict([X_test[..., np.newaxis], X_test[..., np.newaxis]])
#     164 mae = mean_absolute_error(y_test, y_pred)
# --> 165 rmse = mean_squared_error(y_test, y_pred, squared=False)
#     166 r2 = r2_score(y_test, y_pred)
#     168 print(f"[INFO] MAE={mae:.4f} | RMSE={rmse:.4f} | R²={r2:.4f}")
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\utils\_param_validation.py:196, in validate_params.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     193 func_sig = signature(func)
#     195 # Map *args/**kwargs to the function signature
# --> 196 params = func_sig.bind(*args, **kwargs)
#     197 params.apply_defaults()
#     199 # ignore self/cls and positional/keyword markers
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\inspect.py:3195, in Signature.bind(self, *args, **kwargs)
#    3190 def bind(self, /, *args, **kwargs):
#    3191     """Get a BoundArguments object, that maps the passed `args`
#    3192     and `kwargs` to the function's signature.  Raises `TypeError`
#    3193     if the passed arguments can not be bound.
#    3194     """
# -> 3195     return self._bind(args, kwargs)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\inspect.py:3184, in Signature._bind(self, args, kwargs, partial)
#    3182         arguments[kwargs_param.name] = kwargs
#    3183     else:
# -> 3184         raise TypeError(
#    3185             'got an unexpected keyword argument {arg!r}'.format(
#    3186                 arg=next(iter(kwargs))))
#    3188 return self._bound_arguments_cls(self, arguments)
#
# TypeError: got an unexpected keyword argument 'squared'
