# %%
import os
import json
import yaml
import joblib
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
from sklearn.model_selection import train_test_split
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, LSTM, Dense, Conv1D, Flatten, Dropout, concatenate
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.optimizers import Adam
import tensorflow as tf

tf.get_logger().setLevel('ERROR')

# =========================================================
# 📂 PATHS
# =========================================================
BASE_DIR = r"C:\Users\NXTWAVE\Downloads\Flood Prediction & River-Monitoring System"
DATA_PATH = os.path.join(BASE_DIR, "archive", "flood.csv")
VIS_DIR = os.path.join(BASE_DIR, "visuals")
os.makedirs(VIS_DIR, exist_ok=True)

# =========================================================
# 📊 LOAD DATA
# =========================================================
print("[INFO] Loading dataset...")
df = pd.read_csv(DATA_PATH)
print("[INFO] Shape:", df.shape)
print("[INFO] Columns:", df.columns.tolist())

df = df.dropna()

# Last column = FloodProbability (regression target)
y = df.iloc[:, -1].values.reshape(-1, 1)
X = df.iloc[:, :-1].values

scaler = MinMaxScaler()
X_scaled = scaler.fit_transform(X)
joblib.dump(scaler, os.path.join(BASE_DIR, "ais_gwo_stormshield_scaler.pkl"))

X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size=0.2, random_state=42)

# =========================================================
# 🧱 MODEL BUILDER (CNN + LSTM)
# =========================================================
def build_model(lr=0.001, dropout_rate=0.3, units=64):
    # CNN branch
    cnn_input = Input(shape=(X_train.shape[1], 1))
    conv = Conv1D(filters=32, kernel_size=3, activation='relu')(cnn_input)
    flat = Flatten()(conv)

    # LSTM branch
    lstm_input = Input(shape=(X_train.shape[1], 1))
    lstm = LSTM(units, return_sequences=False)(lstm_input)

    # Merge
    merged = concatenate([flat, lstm])
    dense1 = Dense(64, activation='relu')(merged)
    drop = Dropout(dropout_rate)(dense1)
    output = Dense(1, activation='linear')(drop)  # regression output

    model = Model(inputs=[cnn_input, lstm_input], outputs=output)
    model.compile(optimizer=Adam(learning_rate=lr), loss='mse', metrics=['mae'])
    return model

# =========================================================
# 🧬 HYBRID AIS + GWO OPTIMIZER
# =========================================================
def hybrid_ais_gwo(objective_func, dim, bounds, n_agents=4, max_iter=6):
    lb, ub = bounds
    population = np.random.uniform(lb, ub, (n_agents, dim))
    fitness = np.array([objective_func(ind) for ind in population])
    best_idx = np.argmin(fitness)
    best = population[best_idx].copy()
    best_score = fitness[best_idx]

    for t in range(max_iter):
        a = 2 - 2 * (t / max_iter)
        for i in range(n_agents):
            A = 2 * a * np.random.rand(dim) - a
            C = 2 * np.random.rand(dim)
            j = np.random.randint(n_agents)
            D = abs(C * population[j] - population[i])
            X_new = population[j] - A * D

            # AIS mutation
            mutation = np.random.randn(dim) * 0.05
            X_new = np.clip(X_new + mutation, lb, ub)

            new_fit = objective_func(X_new)
            if new_fit < fitness[i]:
                fitness[i] = new_fit
                population[i] = X_new

        best_idx = np.argmin(fitness)
        if fitness[best_idx] < best_score:
            best_score = fitness[best_idx]
            best = population[best_idx].copy()

        print(f"[ITER {t+1}] Best MAE: {best_score:.6f}")

    return best, best_score

# =========================================================
# 🎯 OBJECTIVE FUNCTION (MAE MINIMIZATION)
# =========================================================
def proxy_objective(params):
    lr, dropout_rate, units = params
    units = int(units)
    model = build_model(lr, dropout_rate, units)
    model.fit([X_train[..., np.newaxis], X_train[..., np.newaxis]],
              y_train, epochs=3, batch_size=32, verbose=0)
    loss, mae = model.evaluate([X_test[..., np.newaxis], X_test[..., np.newaxis]], y_test, verbose=0)
    return mae  # minimize MAE

# =========================================================
# ⚙️ RUN OPTIMIZATION
# =========================================================
print("[INFO] Running AIS+GWO optimization...")
best_params, best_score = hybrid_ais_gwo(
    objective_func=lambda x: proxy_objective(x),
    dim=3,
    bounds=([0.0001, 0.1, 32], [0.01, 0.5, 128]),
    n_agents=4,
    max_iter=5
)

best_lr, best_dropout, best_units = best_params
best_units = int(best_units)

with open(os.path.join(BASE_DIR, "ais_gwo_stormshield_config.yaml"), "w") as f:
    yaml.dump({
        'optimizer': 'Hybrid AIS + GWO (Regression)',
        'best_params': {
            'learning_rate': float(best_lr),
            'dropout_rate': float(best_dropout),
            'units': int(best_units)
        },
        'best_MAE': float(best_score)
    }, f)

# =========================================================
# 🧠 FINAL TRAINING
# =========================================================
model = build_model(best_lr, best_dropout, best_units)
early = EarlyStopping(patience=10, restore_best_weights=True)

history_model = model.fit([X_train[..., np.newaxis], X_train[..., np.newaxis]],
                          y_train, validation_split=0.2,
                          epochs=50, batch_size=32,
                          callbacks=[early], verbose=1)

model.save(os.path.join(BASE_DIR, "ais_gwo_stormshield_model.h5"))

# =========================================================
# 📈 EVALUATION & VISUALS
# =========================================================
y_pred = model.predict([X_test[..., np.newaxis], X_test[..., np.newaxis]])
mae = mean_absolute_error(y_test, y_pred)
rmse = mean_squared_error(y_test, y_pred, squared=False)
r2 = r2_score(y_test, y_pred)

print(f"[INFO] MAE={mae:.4f} | RMSE={rmse:.4f} | R²={r2:.4f}")

# Comparison Plot
plt.figure(figsize=(8,4))
plt.plot(y_test[:100], label='Actual')
plt.plot(y_pred[:100], label='Predicted')
plt.legend()
plt.title("Flood Probability (Actual vs Predicted)")
plt.savefig(os.path.join(VIS_DIR, "ais_gwo_stormshield_comparison_graph.png"))
plt.close()

# Loss Curve
plt.figure(figsize=(8,4))
plt.plot(history_model.history['loss'], label='Train')
plt.plot(history_model.history['val_loss'], label='Val')
plt.legend()
plt.title("Loss Curve (MSE)")
plt.savefig(os.path.join(VIS_DIR, "ais_gwo_stormshield_loss_graph.png"))
plt.close()

# Correlation Heatmap
corr = pd.DataFrame(np.hstack((y_test, y_pred)), columns=["True", "Predicted"]).corr()
sns.heatmap(corr, annot=True, cmap="coolwarm")
plt.title("True vs Predicted Correlation")
plt.savefig(os.path.join(VIS_DIR, "ais_gwo_stormshield_heatmap.png"))
plt.close()

# =========================================================
# 💾 SAVE RESULTS
# =========================================================
pred_json = {"MAE": float(mae), "RMSE": float(rmse), "R2": float(r2)}
with open(os.path.join(BASE_DIR, "ais_gwo_stormshield_prediction.json"), "w") as f:
    json.dump(pred_json, f, indent=4)

pd.DataFrame({"True": y_test.flatten(), "Predicted": y_pred.flatten()}).to_csv(
    os.path.join(BASE_DIR, "ais_gwo_stormshield_result.csv"), index=False
)

print("[✅] All files saved successfully in:", BASE_DIR)
# Out:
# [INFO] Loading dataset...
# [INFO] Shape: (50000, 21)
# [INFO] Columns: ['MonsoonIntensity', 'TopographyDrainage', 'RiverManagement', 'Deforestation', 'Urbanization', 'ClimateChange', 'DamsQuality', 'Siltation', 'AgriculturalPractices', 'Encroachments', 'IneffectiveDisasterPreparedness', 'DrainageSystems', 'CoastalVulnerability', 'Landslides', 'Watersheds', 'DeterioratingInfrastructure', 'PopulationScore', 'WetlandLoss', 'InadequatePlanning', 'PoliticalFactors', 'FloodProbability']
# [INFO] Running AIS+GWO optimization...
# [ITER 1] Best MAE: 0.004272
# [ITER 2] Best MAE: 0.002592
# [ITER 3] Best MAE: 0.002067
# [ITER 4] Best MAE: 0.002067
# [ITER 5] Best MAE: 0.002067
# Epoch 1/50
# 1000/1000 [==============================] - 11s 9ms/step - loss: 0.0055 - mae: 0.0442 - val_loss: 7.0386e-05 - val_mae: 0.0066
# Epoch 2/50
# 1000/1000 [==============================] - 9s 9ms/step - loss: 0.0013 - mae: 0.0290 - val_loss: 5.1178e-05 - val_mae: 0.0062
# Epoch 3/50
# 1000/1000 [==============================] - 8s 8ms/step - loss: 0.0012 - mae: 0.0278 - val_loss: 1.7274e-05 - val_mae: 0.0033
# Epoch 4/50
# 1000/1000 [==============================] - 8s 8ms/step - loss: 0.0012 - mae: 0.0269 - val_loss: 3.6004e-05 - val_mae: 0.0051
# Epoch 5/50
# 1000/1000 [==============================] - 9s 9ms/step - loss: 0.0011 - mae: 0.0259 - val_loss: 2.0191e-05 - val_mae: 0.0036
# Epoch 6/50
# 1000/1000 [==============================] - 9s 9ms/step - loss: 9.5627e-04 - mae: 0.0245 - val_loss: 5.6172e-05 - val_mae: 0.0068
# Epoch 7/50
# 1000/1000 [==============================] - 9s 9ms/step - loss: 8.5154e-04 - mae: 0.0231 - val_loss: 3.0040e-05 - val_mae: 0.0048
# Epoch 8/50
# 1000/1000 [==============================] - 9s 9ms/step - loss: 7.5593e-04 - mae: 0.0217 - val_loss: 8.2038e-06 - val_mae: 0.0023
# Epoch 9/50
# 1000/1000 [==============================] - 9s 9ms/step - loss: 6.4086e-04 - mae: 0.0200 - val_loss: 6.9151e-05 - val_mae: 0.0079
# Epoch 10/50
# 1000/1000 [==============================] - 9s 9ms/step - loss: 5.6638e-04 - mae: 0.0187 - val_loss: 6.4716e-06 - val_mae: 0.0020
# Epoch 11/50
# 1000/1000 [==============================] - 9s 9ms/step - loss: 4.7645e-04 - mae: 0.0171 - val_loss: 8.2329e-06 - val_mae: 0.0023
# Epoch 12/50
# 1000/1000 [==============================] - 9s 9ms/step - loss: 4.2367e-04 - mae: 0.0162 - val_loss: 8.8240e-06 - val_mae: 0.0025
# Epoch 13/50
# 1000/1000 [==============================] - 9s 9ms/step - loss: 3.5303e-04 - mae: 0.0147 - val_loss: 4.5424e-06 - val_mae: 0.0017
# Epoch 14/50
# 1000/1000 [==============================] - 9s 9ms/step - loss: 3.0168e-04 - mae: 0.0135 - val_loss: 5.9774e-05 - val_mae: 0.0074
# Epoch 15/50
# 1000/1000 [==============================] - 8s 8ms/step - loss: 2.4659e-04 - mae: 0.0122 - val_loss: 2.9830e-05 - val_mae: 0.0051
# Epoch 16/50
# 1000/1000 [==============================] - 9s 9ms/step - loss: 2.0190e-04 - mae: 0.0110 - val_loss: 2.9788e-05 - val_mae: 0.0051
# Epoch 17/50
# 1000/1000 [==============================] - 9s 9ms/step - loss: 1.6981e-04 - mae: 0.0101 - val_loss: 1.3446e-05 - val_mae: 0.0033
# Epoch 18/50
# 1000/1000 [==============================] - 9s 9ms/step - loss: 1.3482e-04 - mae: 0.0089 - val_loss: 7.3272e-06 - val_mae: 0.0021
# Epoch 19/50
# 1000/1000 [==============================] - 9s 9ms/step - loss: 1.1183e-04 - mae: 0.0081 - val_loss: 9.3936e-06 - val_mae: 0.0023
# Epoch 20/50
# 1000/1000 [==============================] - 9s 9ms/step - loss: 9.3976e-05 - mae: 0.0073 - val_loss: 1.9043e-05 - val_mae: 0.0038
# Epoch 21/50
# 1000/1000 [==============================] - 1687s 2s/step - loss: 7.4528e-05 - mae: 0.0064 - val_loss: 2.0720e-05 - val_mae: 0.0041
# Epoch 22/50
# 1000/1000 [==============================] - 8s 8ms/step - loss: 6.1887e-05 - mae: 0.0058 - val_loss: 6.4147e-06 - val_mae: 0.0022
# Epoch 23/50
# 1000/1000 [==============================] - 9s 9ms/step - loss: 4.8502e-05 - mae: 0.0051 - val_loss: 4.4182e-06 - val_mae: 0.0018
# Epoch 24/50
# 1000/1000 [==============================] - 9s 9ms/step - loss: 4.0051e-05 - mae: 0.0046 - val_loss: 4.1833e-06 - val_mae: 0.0017
# Epoch 25/50
# 1000/1000 [==============================] - 9s 9ms/step - loss: 3.5691e-05 - mae: 0.0043 - val_loss: 8.4896e-06 - val_mae: 0.0026
# Epoch 26/50
# 1000/1000 [==============================] - 9s 9ms/step - loss: 3.2472e-05 - mae: 0.0041 - val_loss: 4.2712e-06 - val_mae: 0.0017
# Epoch 27/50
# 1000/1000 [==============================] - 9s 9ms/step - loss: 2.9757e-05 - mae: 0.0039 - val_loss: 3.0271e-06 - val_mae: 0.0015
# Epoch 28/50
# 1000/1000 [==============================] - 9s 9ms/step - loss: 2.8795e-05 - mae: 0.0038 - val_loss: 2.6111e-06 - val_mae: 0.0012
# Epoch 29/50
# 1000/1000 [==============================] - 9s 9ms/step - loss: 2.7165e-05 - mae: 0.0037 - val_loss: 1.8995e-06 - val_mae: 0.0011
# Epoch 30/50
# 1000/1000 [==============================] - 9s 9ms/step - loss: 2.7294e-05 - mae: 0.0037 - val_loss: 3.5257e-06 - val_mae: 0.0016
# Epoch 31/50
# 1000/1000 [==============================] - 9s 9ms/step - loss: 2.6957e-05 - mae: 0.0036 - val_loss: 1.7443e-06 - val_mae: 0.0011
# Epoch 32/50
# 1000/1000 [==============================] - 9s 9ms/step - loss: 2.7038e-05 - mae: 0.0036 - val_loss: 2.5930e-06 - val_mae: 0.0013
# Epoch 33/50
# 1000/1000 [==============================] - 9s 9ms/step - loss: 2.7034e-05 - mae: 0.0036 - val_loss: 4.5330e-06 - val_mae: 0.0019
# Epoch 34/50
# 1000/1000 [==============================] - 9s 9ms/step - loss: 2.5460e-05 - mae: 0.0036 - val_loss: 2.5358e-06 - val_mae: 0.0012
# Epoch 35/50
# 1000/1000 [==============================] - 9s 9ms/step - loss: 2.5680e-05 - mae: 0.0036 - val_loss: 2.2107e-06 - val_mae: 0.0012
# Epoch 36/50
# 1000/1000 [==============================] - 9s 9ms/step - loss: 2.5330e-05 - mae: 0.0035 - val_loss: 9.7022e-06 - val_mae: 0.0029
# Epoch 37/50
# 1000/1000 [==============================] - 9s 9ms/step - loss: 2.5145e-05 - mae: 0.0035 - val_loss: 2.3764e-06 - val_mae: 0.0013
# Epoch 38/50
# 1000/1000 [==============================] - 9s 9ms/step - loss: 2.4791e-05 - mae: 0.0034 - val_loss: 3.0945e-06 - val_mae: 0.0015
# Epoch 39/50
# 1000/1000 [==============================] - 9s 9ms/step - loss: 2.4337e-05 - mae: 0.0034 - val_loss: 8.9752e-07 - val_mae: 7.1409e-04
# Epoch 40/50
# 1000/1000 [==============================] - 9s 9ms/step - loss: 2.4049e-05 - mae: 0.0034 - val_loss: 1.8900e-06 - val_mae: 0.0012
# Epoch 41/50
# 1000/1000 [==============================] - 9s 9ms/step - loss: 2.3214e-05 - mae: 0.0033 - val_loss: 3.0489e-06 - val_mae: 0.0015
# Epoch 42/50
# 1000/1000 [==============================] - 9s 9ms/step - loss: 2.3509e-05 - mae: 0.0034 - val_loss: 9.3673e-07 - val_mae: 7.4148e-04
# Epoch 43/50
# 1000/1000 [==============================] - 9s 9ms/step - loss: 2.2851e-05 - mae: 0.0033 - val_loss: 2.7995e-06 - val_mae: 0.0013
# Epoch 44/50
# 1000/1000 [==============================] - 9s 9ms/step - loss: 2.3181e-05 - mae: 0.0033 - val_loss: 2.2791e-06 - val_mae: 0.0013
# Epoch 45/50
# 1000/1000 [==============================] - 9s 9ms/step - loss: 2.3580e-05 - mae: 0.0033 - val_loss: 8.5995e-07 - val_mae: 7.3268e-04
# Epoch 46/50
# 1000/1000 [==============================] - 9s 9ms/step - loss: 2.3056e-05 - mae: 0.0033 - val_loss: 5.2760e-06 - val_mae: 0.0019
# Epoch 47/50
# 1000/1000 [==============================] - 9s 9ms/step - loss: 2.3072e-05 - mae: 0.0033 - val_loss: 1.1008e-06 - val_mae: 8.1210e-04
# Epoch 48/50
# 1000/1000 [==============================] - 9s 9ms/step - loss: 2.2481e-05 - mae: 0.0032 - val_loss: 4.2516e-06 - val_mae: 0.0018
# Epoch 49/50
# 1000/1000 [==============================] - 9s 9ms/step - loss: 2.2763e-05 - mae: 0.0033 - val_loss: 1.1257e-06 - val_mae: 8.2682e-04
# Epoch 50/50
# 1000/1000 [==============================] - 9s 9ms/step - loss: 2.2436e-05 - mae: 0.0032 - val_loss: 1.4487e-06 - val_mae: 9.3769e-04
# C:\Users\NXTWAVE\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\engine\training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 313/313 [==============================] - 2s 4ms/step
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[3], line 165
#     163 y_pred = model.predict([X_test[..., np.newaxis], X_test[..., np.newaxis]])
#     164 mae = mean_absolute_error(y_test, y_pred)
# --> 165 rmse = mean_squared_error(y_test, y_pred, squared=False)
#     166 r2 = r2_score(y_test, y_pred)
#     168 print(f"[INFO] MAE={mae:.4f} | RMSE={rmse:.4f} | R²={r2:.4f}")
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\utils\_param_validation.py:196, in validate_params.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     193 func_sig = signature(func)
#     195 # Map *args/**kwargs to the function signature
# --> 196 params = func_sig.bind(*args, **kwargs)
#     197 params.apply_defaults()
#     199 # ignore self/cls and positional/keyword markers
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\inspect.py:3195, in Signature.bind(self, *args, **kwargs)
#    3190 def bind(self, /, *args, **kwargs):
#    3191     """Get a BoundArguments object, that maps the passed `args`
#    3192     and `kwargs` to the function's signature.  Raises `TypeError`
#    3193     if the passed arguments can not be bound.
#    3194     """
# -> 3195     return self._bind(args, kwargs)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\inspect.py:3184, in Signature._bind(self, args, kwargs, partial)
#    3182         arguments[kwargs_param.name] = kwargs
#    3183     else:
# -> 3184         raise TypeError(
#    3185             'got an unexpected keyword argument {arg!r}'.format(
#    3186                 arg=next(iter(kwargs))))
#    3188 return self._bound_arguments_cls(self, arguments)
#
# TypeError: got an unexpected keyword argument 'squared'
